# %%
import numpy as np
import xarray as xr
import pandas as pd
import copy
from datetime import datetime, timedelta
from keras.utils import to_categorical
# import visualkeras
import tensorflow as tf
from model_builders import *
from sklearn.metrics import balanced_accuracy_score
import optuna
from optuna.samplers import TPESampler
import keras
from keras.callbacks import ModelCheckpoint
from sklearn.utils.class_weight import compute_class_weight
import os
import warnings
import joblib
warnings.filterwarnings("ignore", category=UserWarning)

## GLOBAL SEED ##    
np.random.seed(42)
tf.random.set_seed(42)

# %%
def create_tf_datasets(input_data, output_data):
    # Convert xarray dataset to numpy array for TensorFlow Dataset
    input_images = input_data.transpose('time', 'lat', 'lon','channel').values
    output_one_hot = output_data.values

    # Create TensorFlow Datasets
    input_dataset = tf.data.Dataset.from_tensor_slices(input_images)
    output_dataset = tf.data.Dataset.from_tensor_slices(output_one_hot)

    # Combine input and output datasets into a joint dataset
    joint_dataset = tf.data.Dataset.zip((input_dataset, output_dataset))

    return joint_dataset

def create_datasets(input_anoms, var_name, df_shifts, week_out):
# Assuming you have the xarray.Dataset 'input_data' and the pandas.Series 'output_data'
    input_data = copy.deepcopy(input_anoms[var_name])

    array_temp = input_data.data
    array_temp[np.isfinite(array_temp)==False]=0
    input_data.data = array_temp

    input_data = (input_data - input_data.mean('time')) / (input_data.std('time'))
    # Reshape the data to add a new dimension
    values_reshaped = input_data.values.reshape(input_data.shape[0], input_data.shape[1], input_data.shape[2], 1)

    # Create a new xarray.DataArray with the reshaped data and the original coordinates
    input_data = xr.DataArray(values_reshaped, coords=input_data.coords, dims=('time', 'lat', 'lon', 'channel'))
    output_data = copy.deepcopy(df_shifts[f'week{week_out}']).dropna()

    # Step 1: Create a common date index that includes all dates in both the input and output data
    common_dates = np.intersect1d(input_data['time'].values, output_data.index)

    # Step 2: Reindex the input xarray dataset and the output DataFrame to the common date index
    input_data = input_data.sel(time=common_dates)
    output_data = output_data.loc[common_dates]

    # Step 3: One-hot encode the output DataFrame using to_categorical
    num_classes = len(output_data.unique())  # Number of classes (number of weeks in this case)
    output_data_encoded = to_categorical(output_data, num_classes=num_classes)
    output_data_encoded = pd.DataFrame(output_data_encoded,index=output_data.index)

    # Step 4: Create masks for training, validation, and testing periods
    train_mask = (output_data.index >= '1980-01-01') & (output_data.index <= '2010-12-31')
    val_mask = (output_data.index >= '2011-01-01') & (output_data.index <= '2015-12-31')
    test_mask = (output_data.index >= '2016-01-01') & (output_data.index <= '2020-12-31')

    # Step 5: Split the input xarray dataset and the output DataFrame into subsets
    input_train = input_data.sel(time=train_mask)
    input_val = input_data.sel(time=val_mask)
    input_test = input_data.sel(time=test_mask)

    output_train = output_data_encoded.loc[train_mask]
    output_val = output_data_encoded.loc[val_mask]
    output_test = output_data_encoded.loc[test_mask]

    train_joint_dataset = create_tf_datasets(input_train, output_train)
    val_joint_dataset = create_tf_datasets(input_val, output_val)
    test_joint_dataset = create_tf_datasets(input_test, output_test)

    buffer_size = train_joint_dataset.cardinality()
    train_joint_dataset = train_joint_dataset.shuffle(buffer_size)
    return train_joint_dataset, val_joint_dataset, test_joint_dataset

def get_output_from_dataset(dataset):
    output_array = []
    for input_data, output_data in dataset.as_numpy_iterator():
        output_array.append(output_data)

    # Convert the list of NumPy arrays into a single NumPy array
    output_array = np.array(output_array)
    return output_array

def balanced_accuracy(y_true, y_pred):
    y_true = tf.argmax(y_true, axis=1)
    y_pred = tf.argmax(y_pred, axis=1)
    return tf.py_function(balanced_accuracy_score, (y_true, y_pred), tf.float32)

def logging_callback(study, frozen_trial):
    previous_best_value = study.user_attrs.get("previous_best_value", None)
    if previous_best_value != study.best_value:
        study.set_user_attr("previous_best_value", study.best_value)
        print(
            "Trial {} finished with best value: {} and parameters: {}. ".format(
            frozen_trial.number,
            frozen_trial.value,
            frozen_trial.params,
            )
        )

# %%
# def check_dataset_integrity(dataset, name):
#     input_shapes = set()
#     output_shapes = set()
#     num_samples = 0

#     for input_data, output_data in dataset:
#         num_samples += 1
#         input_shapes.add(tuple(input_data.shape.as_list()))
#         output_shapes.add(tuple(output_data.shape.as_list()))

#     print(f"Dataset: {name}")
#     print(f"Input Shapes: {input_shapes}")
#     print(f"Output Shapes: {output_shapes}")
#     print(f"Number of Samples: {num_samples}")


# # Check shapes and number of samples in the training dataset
# check_dataset_integrity(train_joint_dataset, "Training Dataset")

# # Check shapes and number of samples in the validation dataset
# check_dataset_integrity(val_joint_dataset, "Validation Dataset")

# # Check shapes and number of samples in the test dataset
# check_dataset_integrity(test_joint_dataset, "Test Dataset")

# %%
class Objective(object):
    def __init__(self, train_joint_dataset, val_joint_dataset, test_joint_dataset,
                 path_models, variable, week):
        self.train_joint_dataset = train_joint_dataset
        self.val_joint_dataset = val_joint_dataset
        self.test_joint_dataset = test_joint_dataset
        self.path_models = path_models
        self.variable = variable
        self.week = week
 
    def __call__(self, trial):    
        keras.backend.clear_session()
        
        model_base = trial.suggest_categorical('model_base',['vanilla','resnet50','resnet101',\
                                                             'inception','xception','densenet'])
        ks = trial.suggest_categorical('ks',[3,5,7,9,11])
        ps = trial.suggest_categorical('ps',[2,4,6,8])
        type_pooling = trial.suggest_categorical('type_pooling',[None, 'avg','max'])
        stc = trial.suggest_categorical('stc',[1,2,3,4])
        stp = trial.suggest_categorical('stp',[1,2,3,4])
        do = trial.suggest_categorical('do',[0.3,0.4,0.5])
        md = trial.suggest_categorical('md',[2,4,8,16])
        nfilters = trial.suggest_categorical('nfilters',[4,8,16,32])
        activation = trial.suggest_categorical('activation',['LeakyReLU','ReLU'])
        weighted_loss = trial.suggest_categorical('weighted_loss',[True,False])
        
        dict_params = {'model_base':model_base,
                       'ks':ks,
                       'ps':ps,
                       'type_pooling':type_pooling,
                       'stc':stc,
                       'stp':stp,
                       'do':do,
                       'md':md,
                       'nfilters':nfilters,
                       'activation':activation,
                       'weighted_loss':weighted_loss}
        print(dict_params)                                      
        # instantiate and compile model
        if dict_params['model_base']=='vanilla':
            model = build_vanilla_cnn(dict_params['ks'],
                                      dict_params['ps'],
                                      dict_params['type_pooling'],
                                      dict_params['stc'],
                                      dict_params['stp'],
                                      dict_params['do'],
                                      dict_params['md'],
                                      dict_params['nfilters'],
                                      dict_params['activation'])
        elif dict_params['model_base']=='resnet50':
            model = build_resnet50_model(dict_params['type_pooling'],
                                         dict_params['do'],
                                         dict_params['md'],
                                         dict_params['activation'])
        elif dict_params['model_base']=='resnet101':
            model = build_resnet101_model(dict_params['type_pooling'],
                                         dict_params['do'],
                                         dict_params['md'],
                                         dict_params['activation'])
        elif dict_params['model_base']=='inception':
            model = build_inception_model(dict_params['type_pooling'],
                                         dict_params['do'],
                                         dict_params['md'],
                                         dict_params['activation'])
        elif dict_params['model_base']=='xception':
            model = build_xception_model(dict_params['type_pooling'],
                                         dict_params['do'],
                                         dict_params['md'],
                                         dict_params['activation'])
        elif dict_params['model_base']=='densenet':
            model = build_densenet_model(dict_params['type_pooling'],
                                         dict_params['do'],
                                         dict_params['md'],
                                         dict_params['activation'])
            
        model.compile(loss=keras.losses.categorical_crossentropy, 
                optimizer=keras.optimizers.Adam(lr=0.0001),metrics=[balanced_accuracy,'accuracy'])
        
        epochs = 100
        early_stopping_patience = 5

        # Create the EarlyStopping callback
        early_stopping_callback = tf.keras.callbacks.EarlyStopping(
            monitor='val_balanced_accuracy',  # Metric to monitor
            patience=early_stopping_patience,  # Number of epochs with no improvement
            restore_best_weights=True  # Restore the weights of the best model
        )

        # Train the model with early stopping
        try:
            os.mkdir(f'{self.path_models}{self.variable}')
        except: pass
    
        filepath = f'{self.path_models}{self.variable}/model_{self.week}_v9.h5'
        checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=0, save_best_only=True, 
                                     mode='auto',save_weights_only=False)
        
        if dict_params['weighted_loss']==True:
            
            y_train = get_output_from_dataset(self.train_joint_dataset)
            y_train_integers = np.argmax(y_train, axis=1)
            class_weights = compute_class_weight(class_weight='balanced',classes=np.unique(y_train_integers),
                                                 y = y_train_integers)
            d_class_weights = dict(enumerate(class_weights))
            
            history = model.fit(
                self.train_joint_dataset.batch(32),
                validation_data=self.val_joint_dataset.batch(32),
                class_weight = d_class_weights,
                epochs=epochs,
                callbacks=[checkpoint,early_stopping_callback]
            )
        else:
            history = model.fit(
                self.train_joint_dataset.batch(32),
                validation_data=self.val_joint_dataset.batch(32),
                epochs=epochs,
                callbacks=[checkpoint,early_stopping_callback],
                verbose=0
            )
        
        test_loss, test_balanced_accuracy, test_accuracy = model.evaluate(self.test_joint_dataset.batch(32))
        val_balanced_accuracy = np.max(history.history['val_balanced_accuracy'])
        val_accuracy = np.max(history.history['val_accuracy'])
        
        trial.set_user_attr('test_balanced_accuracy',test_balanced_accuracy)
        trial.set_user_attr('test_accuracy',test_accuracy)
        trial.set_user_attr('val_balanced_accuracy',val_balanced_accuracy)
        trial.set_user_attr('val_accuracy',val_accuracy)
        
        return val_balanced_accuracy

# %%
name_var = 'Z500_ERA5'
path_weekly_anoms = '/glade/scratch/jhayron/Data4Predictability/WeeklyAnoms/'
input_anoms = xr.open_dataset(f'{path_weekly_anoms}{name_var}.nc')
var_name = list(input_anoms.data_vars.keys())[0]
week_out = 3
week_out_str = f'week{week_out}'

wr_series = pd.read_csv('/glade/work/jhayron/Data4Predictability/WR_Series.csv',\
                index_col=0,names=['week0'],skiprows=1,parse_dates=True)
for wk in range(2,10):
    series_temp = copy.deepcopy(wr_series["week0"])
    series_temp.index = series_temp.index - timedelta(weeks = wk-1)
    series_temp.name = f'week{wk-1}'
    if wk==2:
        df_shifts = pd.concat([pd.DataFrame(wr_series["week0"]),pd.DataFrame(series_temp)],axis=1)  
    else:
        df_shifts = pd.concat([df_shifts,pd.DataFrame(series_temp)],axis=1)

# %%
train_joint_dataset, val_joint_dataset, test_joint_dataset = \
    create_datasets(input_anoms, var_name, df_shifts, week_out)

# %%
path_models = '/glade/work/jhayron/Data4Predictability/models/CNN/v0/'

# %%
optimizer_direction = 'maximize'
number_of_random_points = 30  # random searches to start opt process
maximum_time = 0.12*60*60  # seconds
objective = Objective(train_joint_dataset,val_joint_dataset,test_joint_dataset,
                      path_models,name_var,week_out_str)
    
results_directory = f'/glade/work/jhayron/Data4Predictability/models/CNN/results_optuna/{week_out_str}/'

try:
    os.mkdir(results_directory)
except:
    pass

study_name = f'study_{name_var}_{week_out_str}_v0'
storage_name = f'sqlite:///{study_name}.db'

optuna.logging.set_verbosity(optuna.logging.WARNING)
study = optuna.create_study(direction=optimizer_direction,
        sampler=TPESampler(n_startup_trials=number_of_random_points),
        study_name=study_name, storage=storage_name,load_if_exists=True)

study.optimize(objective, timeout=maximum_time, gc_after_trial=True,callbacks=[logging_callback],)

# save results
df_results = study.trials_dataframe()
df_results.to_pickle(results_directory + f'df_optuna_results_{name_var}_v0.pkl')
df_results.to_csv(results_directory + f'df_optuna_results_{name_var}_v0.csv')
#save study
joblib.dump(study, results_directory + f'optuna_study_{name_var}_v0.pkl')
# Out:
# {'model_base': 'densenet', 'ks': 11, 'ps': 2, 'type_pooling': None, 'stc': 4, 'stp': 2, 'do': 0.3, 'md': 2, 'nfilters': 4, 'activation': 'ReLU', 'weighted_loss': True}
# Epoch 1/100
# 44/44 [==============================] - 43s 652ms/step - loss: 1.4286 - balanced_accuracy: 0.2512 - accuracy: 0.2067 - val_loss: 1.3899 - val_balanced_accuracy: 0.2604 - val_accuracy: 0.2208
# Epoch 2/100
# 44/44 [==============================] - 27s 598ms/step - loss: 1.3848 - balanced_accuracy: 0.2562 - accuracy: 0.1950 - val_loss: 1.4632 - val_balanced_accuracy: 0.2604 - val_accuracy: 0.2208
# Epoch 3/100
# 44/44 [==============================] - 27s 597ms/step - loss: 1.3626 - balanced_accuracy: 0.2525 - accuracy: 0.2468 - val_loss: 1.3862 - val_balanced_accuracy: 0.2604 - val_accuracy: 0.2727
# Epoch 4/100
# 44/44 [==============================] - 27s 598ms/step - loss: 1.3964 - balanced_accuracy: 0.2494 - accuracy: 0.1980 - val_loss: 1.3862 - val_balanced_accuracy: 0.2188 - val_accuracy: 0.2121
# Epoch 5/100
# 44/44 [==============================] - 27s 599ms/step - loss: 1.4062 - balanced_accuracy: 0.2501 - accuracy: 0.2190 - val_loss: 1.3862 - val_balanced_accuracy: 0.2604 - val_accuracy: 0.2727
# Epoch 6/100
# 44/44 [==============================] - 27s 593ms/step - loss: 1.3820 - balanced_accuracy: 0.2501 - accuracy: 0.2990 - val_loss: 1.3862 - val_balanced_accuracy: 0.2604 - val_accuracy: 0.2727
# 7/7 [==============================] - 1s 171ms/step - loss: 1.3911 - balanced_accuracy: 0.2500 - accuracy: 0.1860
# Trial 0 finished with best value: 0.2604166865348816 and parameters: {'model_base': 'densenet', 'ks': 11, 'ps': 2, 'type_pooling': None, 'stc': 4, 'stp': 2, 'do': 0.3, 'md': 2, 'nfilters': 4, 'activation': 'ReLU', 'weighted_loss': True}.
# {'model_base': 'xception', 'ks': 5, 'ps': 4, 'type_pooling': 'avg', 'stc': 4, 'stp': 1, 'do': 0.5, 'md': 4, 'nfilters': 4, 'activation': 'ReLU', 'weighted_loss': True}
# Epoch 1/100
# 44/44 [==============================] - 51s 1s/step - loss: 1.4013 - balanced_accuracy: 0.2527 - accuracy: 0.2583 - val_loss: 1.3863 - val_balanced_accuracy: 0.2188 - val_accuracy: 0.2121
# Epoch 2/100
# 44/44 [==============================] - 47s 1s/step - loss: 1.3755 - balanced_accuracy: 0.2901 - accuracy: 0.2665 - val_loss: 1.3865 - val_balanced_accuracy: 0.2188 - val_accuracy: 0.2121
# Epoch 3/100
# 44/44 [==============================] - 48s 1s/step - loss: 1.3669 - balanced_accuracy: 0.3122 - accuracy: 0.2927 - val_loss: 1.3871 - val_balanced_accuracy: 0.2188 - val_accuracy: 0.2121
# Epoch 4/100
# 44/44 [==============================] - 47s 1s/step - loss: 1.3252 - balanced_accuracy: 0.3644 - accuracy: 0.3527 - val_loss: 1.3881 - val_balanced_accuracy: 0.2188 - val_accuracy: 0.2121
# Epoch 5/100
# 44/44 [==============================] - 47s 1s/step - loss: 1.2296 - balanced_accuracy: 0.4370 - accuracy: 0.4177 - val_loss: 1.3888 - val_balanced_accuracy: 0.2188 - val_accuracy: 0.2121
# Epoch 6/100
# 44/44 [==============================] - 48s 1s/step - loss: 1.0879 - balanced_accuracy: 0.5099 - accuracy: 0.4845 - val_loss: 1.3871 - val_balanced_accuracy: 0.2188 - val_accuracy: 0.2121
# 7/7 [==============================] - 1s 174ms/step - loss: 1.3859 - balanced_accuracy: 0.2500 - accuracy: 0.2930
# ['/glade/work/jhayron/Data4Predictability/models/CNN/results_optuna/week3/optuna_study_Z500_ERA5_v0.pkl']

# %%
df_results
# Out:
#    number     value             datetime_start          datetime_complete  \
# 0       0  0.260417 2023-07-30 20:59:35.542110 2023-07-30 21:04:57.669291
# 1       1  0.218750 2023-07-30 21:04:58.743773 2023-07-30 21:09:58.680051
#
#                 duration params_activation  params_do  params_ks  params_md  \
# 0 0 days 00:05:22.127181              ReLU        0.3         11          2
# 1 0 days 00:04:59.936278              ReLU        0.5          5          4
#
#   params_model_base  ...  params_ps  params_stc  params_stp  \
# 0          densenet  ...          2           4           2
# 1          xception  ...          4           4           1
#
#    params_type_pooling params_weighted_loss  user_attrs_test_accuracy  \
# 0                 None                 True                  0.186047
# 1                  avg                 True                  0.293023
#
#    user_attrs_test_balanced_accuracy  user_attrs_val_accuracy  \
# 0                               0.25                 0.272727
# 1                               0.25                 0.212121
#
#    user_attrs_val_balanced_accuracy     state
# 0                          0.260417  COMPLETE
# 1                          0.218750  COMPLETE
#
# [2 rows x 21 columns]

# %%
study.trials_dataframe()
# Out:
#     number     value             datetime_start          datetime_complete  \
# 0        0  0.290590 2023-07-30 18:55:52.954667 2023-07-30 18:59:48.385126
# 1        1  0.260417 2023-07-30 18:59:48.788530 2023-07-30 19:01:40.926363
# 2        2  0.218750 2023-07-30 19:01:41.432905 2023-07-30 19:06:35.628478
# 3        3  0.290136 2023-07-30 19:06:35.987198 2023-07-30 19:12:56.481747
# 4        4  0.306908 2023-07-30 19:12:56.992562 2023-07-30 19:18:16.798079
# 5        5  0.272874 2023-07-30 19:18:17.562916 2023-07-30 19:25:21.812051
# 6        6  0.268188 2023-07-30 19:25:22.620584 2023-07-30 19:27:00.393401
# 7        7  0.303073 2023-07-30 19:27:00.808516 2023-07-30 19:30:19.996218
# 8        8  0.260417 2023-07-30 19:30:20.417347 2023-07-30 19:35:11.910293
# 9        9  0.260417 2023-07-30 19:35:12.261241 2023-07-30 19:38:00.927037
# 10      10  0.282629 2023-07-30 19:38:01.442717 2023-07-30 19:40:53.699459
# 11      11  0.260417 2023-07-30 19:40:54.052875 2023-07-30 19:42:30.074304
# 12      12  0.378669 2023-07-30 19:42:30.481790 2023-07-30 19:43:54.041340
# 13      13  0.266625 2023-07-30 19:43:54.260528 2023-07-30 19:47:58.163285
# 14      14  0.286388 2023-07-30 19:47:58.979745 2023-07-30 19:52:37.254404
# 15      15  0.260417 2023-07-30 19:52:37.733438 2023-07-30 19:54:16.146632
# 16      16  0.260417 2023-07-30 19:54:16.493284 2023-07-30 19:59:03.512243
#
#                  duration params_activation  params_do  params_ks  params_md  \
# 0  0 days 00:03:55.430459         LeakyReLU        0.5          7          4
# 1  0 days 00:01:52.137833              ReLU        0.3          5         16
# 2  0 days 00:04:54.195573              ReLU        0.4          9          2
# 3  0 days 00:06:20.494549         LeakyReLU        0.4         11          2
# 4  0 days 00:05:19.805517              ReLU        0.3          7         16
# 5  0 days 00:07:04.249135              ReLU        0.4          3          2
# 6  0 days 00:01:37.772817         LeakyReLU        0.4          5          4
# 7  0 days 00:03:19.187702         LeakyReLU        0.4          5          8
# 8  0 days 00:04:51.492946         LeakyReLU        0.5          9          4
# 9  0 days 00:02:48.665796              ReLU        0.5          9          2
# 10 0 days 00:02:52.256742              ReLU        0.4          7          4
# 11 0 days 00:01:36.021429         LeakyReLU        0.4          5          4
# 12 0 days 00:01:23.559550         LeakyReLU        0.5          9          8
# 13 0 days 00:04:03.902757         LeakyReLU        0.5          9          4
# 14 0 days 00:04:38.274659         LeakyReLU        0.4          7         16
# 15 0 days 00:01:38.413194              ReLU        0.4         11          2
# 16 0 days 00:04:47.018959              ReLU        0.5          9          8
#
#    params_model_base  params_nfilters  params_ps  params_stc  params_stp  \
# 0           resnet50                4          6           4           3
# 1           resnet50                8          8           2           4
# 2           xception               16          6           4           2
# 3          resnet101                4          4           1           4
# 4          inception                4          4           3           4
# 5           densenet                4          4           3           1
# 6          inception               32          6           3           3
# 7          inception                4          8           2           4
# 8           xception               16          8           1           3
# 9          resnet101               32          8           3           4
# 10          resnet50                8          6           1           2
# 11         inception                4          6           2           3
# 12           vanilla                4          4           1           3
# 13          densenet               32          8           4           4
# 14         resnet101                4          6           4           1
# 15          resnet50                4          2           1           3
# 16          xception               32          4           4           4
#
#    params_type_pooling  params_weighted_loss     state
# 0                  max                 False  COMPLETE
# 1                  max                  True  COMPLETE
# 2                  avg                  True  COMPLETE
# 3                  avg                  True  COMPLETE
# 4                  max                  True  COMPLETE
# 5                  max                  True  COMPLETE
# 6                  max                 False  COMPLETE
# 7                  max                 False  COMPLETE
# 8                  avg                  True  COMPLETE
# 9                  avg                  True  COMPLETE
# 10                 avg                 False  COMPLETE
# 11                None                 False  COMPLETE
# 12                 max                 False  COMPLETE
# 13                None                 False  COMPLETE
# 14                 avg                 False  COMPLETE
# 15                 avg                 False  COMPLETE
# 16                 avg                 False  COMPLETE

# %%
# Parameters to test

#### 1. type_pooling
#### 2.

# %%
#### Vanilla types

# %%
variables = ['z500','olr', 'sst', 'u10', 'sm_region', 'st_region']
name_var = ['z500','olr', 'sst', 'u10', 'sm', 'st']
units = ['m2/s2','J/m2','K','m/s','m3/m3','K']

# %%
for var_short, variable,unit in zip(name_var,variables,units):
    # for week in ['week1','week2','week3','week4','week5','week6']:
    for week in ['week3']:
        results_directory = f'/glade/scratch/jhayron/Weather_Regimes/models/CNN/results_optuna/{week}/'
        # study_optuna = joblib.load(results_directory + f'optuna_study_{var_short}_v4_acc.pkl')
        aaaa
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 6
#       4 results_directory = f'/glade/scratch/jhayron/Weather_Regimes/models/CNN/results_optuna/{week}/'
#       5 study_optuna = joblib.load(results_directory + f'optuna_study_{var_short}_v4_acc.pkl')
# ----> 6 aaaa
#
# NameError: name 'aaaa' is not defined

# %%
df_results = pd.read_csv(results_directory + f'df_optuna_results_olr_v4_acc.csv',index_col=1)

print(df_results[df_results.value==df_results.value.min()]\
    [['params_ks','params_nfilters','params_ps','params_stc','params_stp']])
# Out:
#         params_ks  params_nfilters  params_ps  params_stc  params_stp
# number
# 296             9               16          4           3           1

# %%
df_results[df_results.value==df_results.value.min()]
# Out:
#         Unnamed: 0     value              datetime_start  \
# number
# 296            296  0.200855  2023-04-16 21:47:44.863815
#
#                  datetime_complete                duration params_activation  \
# number
# 296     2023-04-16 21:47:52.692154  0 days 00:00:07.828339         LeakyReLU
#
#         params_bn  params_bs  params_do  params_ks  params_md  \
# number
# 296         False        128        0.3          9         32
#
#         params_nfilters  params_ps  params_stc  params_stp  \
# number
# 296                  16          4           3           1
#
#        params_type_pooling  params_wl     state
# number
# 296                    Max      False  COMPLETE

# %%
df_results.keys()
# Out:
# Index(['Unnamed: 0', 'value', 'datetime_start', 'datetime_complete',
#        'duration', 'params_activation', 'params_bn', 'params_bs', 'params_do',
#        'params_ks', 'params_md', 'params_nfilters', 'params_ps', 'params_stc',
#        'params_stp', 'params_type_pooling', 'params_wl', 'state'],
#       dtype='object')

# %%
12*24*9
# Out:
# 2592

# %%
df_results[df_results.value==df_results.value.min()].params_ks

# %%
model = build_resnet101_model('avg',0.5,8,'LeakyReLU')
model.compile(loss=keras.losses.categorical_crossentropy, 
                optimizer=keras.optimizers.Adam(lr=0.0001),metrics=[balanced_accuracy,'accuracy'])

# %%
# Create the EarlyStopping callback
epochs = 100
early_stopping_patience = 5
early_stopping_callback = tf.keras.callbacks.EarlyStopping(
    monitor='val_balanced_accuracy',  # Metric to monitor
    patience=early_stopping_patience,  # Number of epochs with no improvement
    restore_best_weights=True  # Restore the weights of the best model
)

# %%
y_train = get_output_from_dataset(train_joint_dataset)
y_train_integers = np.argmax(y_train, axis=1)
class_weights = compute_class_weight(class_weight='balanced',classes=np.unique(y_train_integers),
                                     y = y_train_integers)
d_class_weights = dict(enumerate(class_weights))

history = model.fit(
    train_joint_dataset.batch(16),
    validation_data=val_joint_dataset.batch(16),
    class_weight = d_class_weights,
    epochs=epochs,
    callbacks=[early_stopping_callback]
)
# Out:
# 2023-07-30 16:39:27.350915: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2023-07-30 16:39:27.353584: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2300000000 Hz
# Epoch 1/100
# 2023-07-30 16:39:40.213232: W tensorflow/core/common_runtime/bfc_allocator.cc:433] Allocator (GPU_0_bfc) ran out of memory trying to allocate 9.00MiB (rounded to 9437184)requested by op Fill
# Current allocation summary follows.
# 2023-07-30 16:39:40.213490: I tensorflow/core/common_runtime/bfc_allocator.cc:972] BFCAllocator dump for GPU_0_bfc
# 2023-07-30 16:39:40.213506: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (256): 	Total Chunks: 329, Chunks in use: 329. 82.2KiB allocated for chunks. 82.2KiB in use in bin. 34.0KiB client-requested in use in bin.
# 2023-07-30 16:39:40.213515: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (512): 	Total Chunks: 147, Chunks in use: 147. 73.5KiB allocated for chunks. 73.5KiB in use in bin. 73.5KiB client-requested in use in bin.
# 2023-07-30 16:39:40.213523: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (1024): 	Total Chunks: 906, Chunks in use: 906. 908.0KiB allocated for chunks. 908.0KiB in use in bin. 906.0KiB client-requested in use in bin.
# 2023-07-30 16:39:40.213531: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (2048): 	Total Chunks: 175, Chunks in use: 175. 363.0KiB allocated for chunks. 363.0KiB in use in bin. 350.0KiB client-requested in use in bin.
# 2023-07-30 16:39:40.213538: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (4096): 	Total Chunks: 534, Chunks in use: 534. 2.12MiB allocated for chunks. 2.12MiB in use in bin. 2.09MiB client-requested in use in bin.
# 2023-07-30 16:39:40.213546: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (8192): 	Total Chunks: 55, Chunks in use: 55. 462.5KiB allocated for chunks. 462.5KiB in use in bin. 452.8KiB client-requested in use in bin.
# 2023-07-30 16:39:40.213554: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (16384): 	Total Chunks: 7, Chunks in use: 7. 122.5KiB allocated for chunks. 122.5KiB in use in bin. 104.5KiB client-requested in use in bin.
# 2023-07-30 16:39:40.213561: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (32768): 	Total Chunks: 3, Chunks in use: 3. 106.5KiB allocated for chunks. 106.5KiB in use in bin. 96.0KiB client-requested in use in bin.
# 2023-07-30 16:39:40.213568: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (65536): 	Total Chunks: 30, Chunks in use: 30. 2.15MiB allocated for chunks. 2.15MiB in use in bin. 1.88MiB client-requested in use in bin.
# 2023-07-30 16:39:40.213575: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (131072): 	Total Chunks: 19, Chunks in use: 19. 2.92MiB allocated for chunks. 2.92MiB in use in bin. 2.59MiB client-requested in use in bin.
# 2023-07-30 16:39:40.213583: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (262144): 	Total Chunks: 37, Chunks in use: 36. 10.68MiB allocated for chunks. 10.38MiB in use in bin. 8.89MiB client-requested in use in bin.
# 2023-07-30 16:39:40.213591: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (524288): 	Total Chunks: 28, Chunks in use: 28. 20.33MiB allocated for chunks. 20.33MiB in use in bin. 15.12MiB client-requested in use in bin.
# 2023-07-30 16:39:40.213599: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (1048576): 	Total Chunks: 227, Chunks in use: 227. 256.31MiB allocated for chunks. 256.31MiB in use in bin. 226.12MiB client-requested in use in bin.
# 2023-07-30 16:39:40.213607: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (2097152): 	Total Chunks: 124, Chunks in use: 124. 288.46MiB allocated for chunks. 288.46MiB in use in bin. 276.00MiB client-requested in use in bin.
# 2023-07-30 16:39:40.213614: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (4194304): 	Total Chunks: 20, Chunks in use: 20. 86.87MiB allocated for chunks. 86.87MiB in use in bin. 74.75MiB client-requested in use in bin.
# 2023-07-30 16:39:40.213622: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (8388608): 	Total Chunks: 16, Chunks in use: 16. 142.27MiB allocated for chunks. 142.27MiB in use in bin. 138.00MiB client-requested in use in bin.
# 2023-07-30 16:39:40.213629: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (16777216): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-07-30 16:39:40.213637: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (33554432): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-07-30 16:39:40.213644: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (67108864): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-07-30 16:39:40.213650: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (134217728): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-07-30 16:39:40.213657: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (268435456): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-07-30 16:39:40.213664: I tensorflow/core/common_runtime/bfc_allocator.cc:995] Bin for 9.00MiB was 8.00MiB, Chunk State:
# 2023-07-30 16:39:40.213670: I tensorflow/core/common_runtime/bfc_allocator.cc:1008] Next region of size 853737472
# 2023-07-30 16:39:40.213680: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e000000 of size 256 next 1
# 2023-07-30 16:39:40.213687: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e000100 of size 256 next 2
# 2023-07-30 16:39:40.213693: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e000200 of size 1280 next 3
# 2023-07-30 16:39:40.213699: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e000700 of size 256 next 4
# 2023-07-30 16:39:40.213705: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e000800 of size 256 next 5
# 2023-07-30 16:39:40.213710: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e000900 of size 256 next 6
# 2023-07-30 16:39:40.213716: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e000a00 of size 256 next 10
# 2023-07-30 16:39:40.213722: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e000b00 of size 256 next 13
# 2023-07-30 16:39:40.213728: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e000c00 of size 256 next 14
# 2023-07-30 16:39:40.213733: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e000d00 of size 256 next 18
# 2023-07-30 16:39:40.213739: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e000e00 of size 256 next 7
# 2023-07-30 16:39:40.213744: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e000f00 of size 256 next 8
# 2023-07-30 16:39:40.213750: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e001000 of size 256 next 9
# 2023-07-30 16:39:40.213756: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e001100 of size 256 next 16
# 2023-07-30 16:39:40.213761: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e001200 of size 256 next 17
# 2023-07-30 16:39:40.213767: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e001300 of size 256 next 19
# 2023-07-30 16:39:40.213773: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e001400 of size 256 next 20
# 2023-07-30 16:39:40.213778: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e001500 of size 256 next 157
# 2023-07-30 16:39:40.213784: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e001600 of size 256 next 160
# 2023-07-30 16:39:40.213790: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e001700 of size 256 next 148
# 2023-07-30 16:39:40.213795: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e001800 of size 256 next 163
# 2023-07-30 16:39:40.213801: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e001900 of size 256 next 164
# 2023-07-30 16:39:40.213806: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e001a00 of size 256 next 152
# 2023-07-30 16:39:40.213813: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e001b00 of size 256 next 153
# 2023-07-30 16:39:40.213819: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e001c00 of size 256 next 168
# 2023-07-30 16:39:40.213824: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e001d00 of size 256 next 24
# 2023-07-30 16:39:40.213830: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e001e00 of size 256 next 26
# 2023-07-30 16:39:40.213836: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e001f00 of size 256 next 27
# 2023-07-30 16:39:40.213843: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e002000 of size 1024 next 174
# 2023-07-30 16:39:40.213848: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e002400 of size 1024 next 175
# 2023-07-30 16:39:40.213854: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e002800 of size 1024 next 40
# 2023-07-30 16:39:40.213860: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e002c00 of size 256 next 42
# 2023-07-30 16:39:40.213866: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e002d00 of size 256 next 43
# 2023-07-30 16:39:40.213871: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e002e00 of size 1024 next 185
# 2023-07-30 16:39:40.213877: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e003200 of size 1024 next 187
# 2023-07-30 16:39:40.213883: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e003600 of size 512 next 191
# 2023-07-30 16:39:40.213889: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e003800 of size 512 next 48
# 2023-07-30 16:39:40.213895: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e003a00 of size 256 next 50
# 2023-07-30 16:39:40.213900: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e003b00 of size 256 next 51
# 2023-07-30 16:39:40.213906: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e003c00 of size 1024 next 55
# 2023-07-30 16:39:40.213912: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e004000 of size 256 next 57
# 2023-07-30 16:39:40.213917: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e004100 of size 256 next 58
# 2023-07-30 16:39:40.213923: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e004200 of size 256 next 69
# 2023-07-30 16:39:40.213928: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e004300 of size 256 next 70
# 2023-07-30 16:39:40.213934: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e004400 of size 256 next 56
# 2023-07-30 16:39:40.213940: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e004500 of size 256 next 62
# 2023-07-30 16:39:40.213945: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e004600 of size 256 next 64
# 2023-07-30 16:39:40.213951: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e004700 of size 256 next 65
# 2023-07-30 16:39:40.213957: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e004800 of size 1024 next 117
# 2023-07-30 16:39:40.213962: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e004c00 of size 1024 next 74
# 2023-07-30 16:39:40.213968: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e005000 of size 256 next 76
# 2023-07-30 16:39:40.213974: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e005100 of size 256 next 77
# 2023-07-30 16:39:40.213979: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e005200 of size 1024 next 118
# 2023-07-30 16:39:40.213985: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e005600 of size 256 next 108
# 2023-07-30 16:39:40.213991: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e005700 of size 256 next 122
# 2023-07-30 16:39:40.213997: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e005800 of size 256 next 123
# 2023-07-30 16:39:40.214003: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e005900 of size 256 next 81
# 2023-07-30 16:39:40.214008: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e005a00 of size 256 next 82
# 2023-07-30 16:39:40.214014: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e005b00 of size 256 next 83
# 2023-07-30 16:39:40.214019: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e005c00 of size 256 next 111
# 2023-07-30 16:39:40.214025: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e005d00 of size 256 next 114
# 2023-07-30 16:39:40.214031: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e005e00 of size 256 next 127
# 2023-07-30 16:39:40.214036: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e005f00 of size 1280 next 89
# 2023-07-30 16:39:40.214042: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e006400 of size 256 next 91
# 2023-07-30 16:39:40.214048: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e006500 of size 256 next 92
# 2023-07-30 16:39:40.214053: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e006600 of size 256 next 49
# 2023-07-30 16:39:40.214059: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e006700 of size 256 next 63
# 2023-07-30 16:39:40.214065: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e006800 of size 256 next 86
# 2023-07-30 16:39:40.214070: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e006900 of size 256 next 97
# 2023-07-30 16:39:40.214076: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e006a00 of size 256 next 99
# 2023-07-30 16:39:40.214081: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e006b00 of size 256 next 100
# 2023-07-30 16:39:40.214087: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e006c00 of size 1024 next 105
# 2023-07-30 16:39:40.214093: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e007000 of size 256 next 106
# 2023-07-30 16:39:40.214098: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e007100 of size 256 next 107
# 2023-07-30 16:39:40.214104: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e007200 of size 256 next 25
# 2023-07-30 16:39:40.214110: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e007300 of size 256 next 33
# 2023-07-30 16:39:40.214115: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e007400 of size 256 next 34
# 2023-07-30 16:39:40.214121: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e007500 of size 256 next 35
# 2023-07-30 16:39:40.214127: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e007600 of size 2048 next 288
# 2023-07-30 16:39:40.214133: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e007e00 of size 512 next 289
# 2023-07-30 16:39:40.214138: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e008000 of size 512 next 267
# 2023-07-30 16:39:40.214150: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e008200 of size 512 next 293
# 2023-07-30 16:39:40.214155: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e008400 of size 512 next 294
# 2023-07-30 16:39:40.214161: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e008600 of size 512 next 271
# 2023-07-30 16:39:40.214167: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e008800 of size 512 next 298
# 2023-07-30 16:39:40.214172: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e008a00 of size 512 next 299
# 2023-07-30 16:39:40.214195: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e008c00 of size 512 next 259
# 2023-07-30 16:39:40.214202: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e008e00 of size 512 next 311
# 2023-07-30 16:39:40.214208: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e009000 of size 512 next 333
# 2023-07-30 16:39:40.214214: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e009200 of size 512 next 138
# 2023-07-30 16:39:40.214220: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e009400 of size 256 next 139
# 2023-07-30 16:39:40.214226: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e009500 of size 256 next 140
# 2023-07-30 16:39:40.214231: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e009600 of size 1024 next 145
# 2023-07-30 16:39:40.214237: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e009a00 of size 256 next 146
# 2023-07-30 16:39:40.214243: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e009b00 of size 256 next 147
# 2023-07-30 16:39:40.214249: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e009c00 of size 2048 next 281
# 2023-07-30 16:39:40.214255: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e00a400 of size 2048 next 303
# 2023-07-30 16:39:40.214261: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e00ac00 of size 2048 next 306
# 2023-07-30 16:39:40.214267: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e00b400 of size 2048 next 178
# 2023-07-30 16:39:40.214273: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e00bc00 of size 256 next 180
# 2023-07-30 16:39:40.214279: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e00bd00 of size 256 next 181
# 2023-07-30 16:39:40.214285: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e00be00 of size 83968 next 264
# 2023-07-30 16:39:40.214291: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e020600 of size 256 next 265
# 2023-07-30 16:39:40.214297: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e020700 of size 256 next 266
# 2023-07-30 16:39:40.214320: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e020800 of size 512 next 241
# 2023-07-30 16:39:40.214326: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e020a00 of size 512 next 220
# 2023-07-30 16:39:40.214332: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e020c00 of size 512 next 244
# 2023-07-30 16:39:40.214338: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e020e00 of size 512 next 246
# 2023-07-30 16:39:40.214344: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e021000 of size 512 next 224
# 2023-07-30 16:39:40.214350: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e021200 of size 512 next 249
# 2023-07-30 16:39:40.214356: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e021400 of size 512 next 250
# 2023-07-30 16:39:40.214362: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e021600 of size 512 next 254
# 2023-07-30 16:39:40.214369: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e021800 of size 2048 next 276
# 2023-07-30 16:39:40.214375: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e022000 of size 256 next 277
# 2023-07-30 16:39:40.214381: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e022100 of size 256 next 278
# 2023-07-30 16:39:40.214387: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e022200 of size 2048 next 348
# 2023-07-30 16:39:40.214393: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e022a00 of size 4096 next 314
# 2023-07-30 16:39:40.214400: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e023a00 of size 1024 next 327
# 2023-07-30 16:39:40.214406: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e023e00 of size 1024 next 330
# 2023-07-30 16:39:40.214413: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e024200 of size 1024 next 352
# 2023-07-30 16:39:40.214419: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e024600 of size 1024 next 355
# 2023-07-30 16:39:40.214425: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e024a00 of size 1024 next 385
# 2023-07-30 16:39:40.214431: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e024e00 of size 1024 next 387
# 2023-07-30 16:39:40.214438: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e025200 of size 1024 next 390
# 2023-07-30 16:39:40.214444: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e025600 of size 1024 next 393
# 2023-07-30 16:39:40.214450: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e025a00 of size 1024 next 401
# 2023-07-30 16:39:40.214456: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e025e00 of size 1024 next 36
# 2023-07-30 16:39:40.214463: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e026200 of size 16384 next 41
# 2023-07-30 16:39:40.214469: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e02a200 of size 4096 next 373
# 2023-07-30 16:39:40.214475: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e02b200 of size 1024 next 403
# 2023-07-30 16:39:40.214481: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e02b600 of size 1024 next 363
# 2023-07-30 16:39:40.214487: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e02ba00 of size 1024 next 380
# 2023-07-30 16:39:40.214493: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e02be00 of size 1024 next 381
# 2023-07-30 16:39:40.214500: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e02c200 of size 1024 next 405
# 2023-07-30 16:39:40.214506: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e02c600 of size 1024 next 407
# 2023-07-30 16:39:40.214512: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e02ca00 of size 4096 next 411
# 2023-07-30 16:39:40.214518: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e02da00 of size 4096 next 427
# 2023-07-30 16:39:40.214524: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e02ea00 of size 4096 next 428
# 2023-07-30 16:39:40.214530: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e02fa00 of size 6144 next 201
# 2023-07-30 16:39:40.214536: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e031200 of size 256 next 202
# 2023-07-30 16:39:40.214543: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e031300 of size 256 next 203
# 2023-07-30 16:39:40.214549: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e031400 of size 3072 next 209
# 2023-07-30 16:39:40.214555: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e032000 of size 256 next 210
# 2023-07-30 16:39:40.214561: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e032100 of size 256 next 211
# 2023-07-30 16:39:40.214567: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e032200 of size 1024 next 133
# 2023-07-30 16:39:40.214574: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e032600 of size 1024 next 216
# 2023-07-30 16:39:40.214580: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e032a00 of size 256 next 217
# 2023-07-30 16:39:40.214586: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e032b00 of size 256 next 218
# 2023-07-30 16:39:40.214592: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e032c00 of size 1024 next 134
# 2023-07-30 16:39:40.214598: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e033000 of size 1024 next 223
# 2023-07-30 16:39:40.214604: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e033400 of size 256 next 225
# 2023-07-30 16:39:40.214611: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e033500 of size 256 next 226
# 2023-07-30 16:39:40.214617: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e033600 of size 1024 next 488
# 2023-07-30 16:39:40.214623: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e033a00 of size 1024 next 487
# 2023-07-30 16:39:40.214630: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e033e00 of size 1024 next 465
# 2023-07-30 16:39:40.214636: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e034200 of size 1024 next 464
# 2023-07-30 16:39:40.214642: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e034600 of size 1024 next 469
# 2023-07-30 16:39:40.214648: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e034a00 of size 1024 next 474
# 2023-07-30 16:39:40.214654: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e034e00 of size 1024 next 455
# 2023-07-30 16:39:40.214660: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e035200 of size 1024 next 496
# 2023-07-30 16:39:40.214666: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e035600 of size 4096 next 471
# 2023-07-30 16:39:40.214673: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e036600 of size 4096 next 477
# 2023-07-30 16:39:40.214679: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e037600 of size 4096 next 476
# 2023-07-30 16:39:40.214685: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e038600 of size 4096 next 494
# 2023-07-30 16:39:40.214691: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e039600 of size 4096 next 493
# 2023-07-30 16:39:40.214697: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e03a600 of size 1024 next 499
# 2023-07-30 16:39:40.214703: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e03aa00 of size 1024 next 498
# 2023-07-30 16:39:40.214709: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e03ae00 of size 1024 next 457
# 2023-07-30 16:39:40.214715: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e03b200 of size 1024 next 456
# 2023-07-30 16:39:40.214721: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e03b600 of size 1024 next 537
# 2023-07-30 16:39:40.214727: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e03ba00 of size 1024 next 536
# 2023-07-30 16:39:40.214734: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e03be00 of size 1024 next 518
# 2023-07-30 16:39:40.214740: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e03c200 of size 1024 next 517
# 2023-07-30 16:39:40.214746: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e03c600 of size 4096 next 520
# 2023-07-30 16:39:40.214752: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e03d600 of size 4096 next 543
# 2023-07-30 16:39:40.214758: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e03e600 of size 4096 next 542
# 2023-07-30 16:39:40.214764: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e03f600 of size 4096 next 510
# 2023-07-30 16:39:40.214770: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e040600 of size 4096 next 525
# 2023-07-30 16:39:40.214776: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e041600 of size 1024 next 524
# 2023-07-30 16:39:40.214782: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e041a00 of size 1024 next 529
# 2023-07-30 16:39:40.214788: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e041e00 of size 1024 next 528
# 2023-07-30 16:39:40.214795: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e042200 of size 1024 next 547
# 2023-07-30 16:39:40.214801: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e042600 of size 1024 next 513
# 2023-07-30 16:39:40.214807: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e042a00 of size 1024 next 512
# 2023-07-30 16:39:40.214813: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e042e00 of size 1024 next 556
# 2023-07-30 16:39:40.214820: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e043200 of size 1024 next 555
# 2023-07-30 16:39:40.214826: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e043600 of size 4096 next 2163
# 2023-07-30 16:39:40.214832: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e044600 of size 4096 next 2164
# 2023-07-30 16:39:40.214838: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e045600 of size 4096 next 2165
# 2023-07-30 16:39:40.214844: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e046600 of size 4096 next 2166
# 2023-07-30 16:39:40.214850: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e047600 of size 4096 next 2167
# 2023-07-30 16:39:40.214856: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e048600 of size 1024 next 2168
# 2023-07-30 16:39:40.214863: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e048a00 of size 1024 next 2169
# 2023-07-30 16:39:40.214869: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e048e00 of size 1024 next 2170
# 2023-07-30 16:39:40.214875: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e049200 of size 1024 next 2171
# 2023-07-30 16:39:40.214881: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e049600 of size 1024 next 2174
# 2023-07-30 16:39:40.214887: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e049a00 of size 1024 next 2175
# 2023-07-30 16:39:40.214893: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e049e00 of size 1024 next 2176
# 2023-07-30 16:39:40.214899: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e04a200 of size 1024 next 2177
# 2023-07-30 16:39:40.214905: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e04a600 of size 4096 next 2179
# 2023-07-30 16:39:40.214911: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e04b600 of size 4096 next 2180
# 2023-07-30 16:39:40.214918: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e04c600 of size 4096 next 2181
# 2023-07-30 16:39:40.214924: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e04d600 of size 4096 next 2182
# 2023-07-30 16:39:40.214930: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e04e600 of size 4096 next 2183
# 2023-07-30 16:39:40.214936: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e04f600 of size 8192 next 2184
# 2023-07-30 16:39:40.214942: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e051600 of size 2048 next 2189
# 2023-07-30 16:39:40.214948: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e051e00 of size 2048 next 2190
# 2023-07-30 16:39:40.214954: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e052600 of size 2048 next 2191
# 2023-07-30 16:39:40.214961: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e052e00 of size 2048 next 2192
# 2023-07-30 16:39:40.214967: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e053600 of size 256 next 2193
# 2023-07-30 16:39:40.214973: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e053700 of size 2048 next 2196
# 2023-07-30 16:39:40.214979: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e053f00 of size 2048 next 2197
# 2023-07-30 16:39:40.214985: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e054700 of size 2048 next 2198
# 2023-07-30 16:39:40.214991: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e054f00 of size 2048 next 2199
# 2023-07-30 16:39:40.214998: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e055700 of size 256 next 2201
# 2023-07-30 16:39:40.215004: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e055800 of size 256 next 2202
# 2023-07-30 16:39:40.215010: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e055900 of size 8192 next 2200
# 2023-07-30 16:39:40.215016: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e057900 of size 8192 next 2204
# 2023-07-30 16:39:40.215022: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e059900 of size 8192 next 2205
# 2023-07-30 16:39:40.215029: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e05b900 of size 8192 next 2206
# 2023-07-30 16:39:40.215035: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e05d900 of size 8192 next 2207
# 2023-07-30 16:39:40.215041: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e05f900 of size 2048 next 2208
# 2023-07-30 16:39:40.215047: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e060100 of size 2048 next 2210
# 2023-07-30 16:39:40.215053: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e060900 of size 2048 next 2211
# 2023-07-30 16:39:40.215059: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e061100 of size 2048 next 2212
# 2023-07-30 16:39:40.215065: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e061900 of size 2048 next 2213
# 2023-07-30 16:39:40.215071: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e062100 of size 2048 next 2216
# 2023-07-30 16:39:40.215077: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e062900 of size 2048 next 2217
# 2023-07-30 16:39:40.215083: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e063100 of size 2048 next 2218
# 2023-07-30 16:39:40.215090: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e063900 of size 8192 next 2219
# 2023-07-30 16:39:40.215096: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e065900 of size 8192 next 2221
# 2023-07-30 16:39:40.215102: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e067900 of size 8192 next 2222
# 2023-07-30 16:39:40.215108: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e069900 of size 8192 next 2223
# 2023-07-30 16:39:40.215114: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e06b900 of size 8192 next 2224
# 2023-07-30 16:39:40.215120: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e06d900 of size 2048 next 2226
# 2023-07-30 16:39:40.215126: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e06e100 of size 2048 next 2227
# 2023-07-30 16:39:40.215132: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e06e900 of size 2048 next 2228
# 2023-07-30 16:39:40.215138: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e06f100 of size 2048 next 2229
# 2023-07-30 16:39:40.215148: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e06f900 of size 2048 next 2232
# 2023-07-30 16:39:40.215154: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e070100 of size 2048 next 2233
# 2023-07-30 16:39:40.215160: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e070900 of size 2048 next 2234
# 2023-07-30 16:39:40.215166: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e071100 of size 2048 next 2235
# 2023-07-30 16:39:40.215173: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e071900 of size 8192 next 2237
# 2023-07-30 16:39:40.215179: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e073900 of size 8192 next 2238
# 2023-07-30 16:39:40.215185: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e075900 of size 16128 next 483
# 2023-07-30 16:39:40.215192: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e079800 of size 256 next 485
# 2023-07-30 16:39:40.215198: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e079900 of size 256 next 486
# 2023-07-30 16:39:40.215204: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e079a00 of size 4096 next 369
# 2023-07-30 16:39:40.215210: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e07aa00 of size 4096 next 396
# 2023-07-30 16:39:40.215216: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e07ba00 of size 4096 next 398
# 2023-07-30 16:39:40.215222: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e07ca00 of size 6144 next 500
# 2023-07-30 16:39:40.215229: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e07e200 of size 256 next 501
# 2023-07-30 16:39:40.215235: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e07e300 of size 256 next 502
# 2023-07-30 16:39:40.215241: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e07e400 of size 512 next 195
# 2023-07-30 16:39:40.215247: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e07e600 of size 512 next 196
# 2023-07-30 16:39:40.215253: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e07e800 of size 512 next 231
# 2023-07-30 16:39:40.215259: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e07ea00 of size 512 next 233
# 2023-07-30 16:39:40.215265: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e07ec00 of size 512 next 236
# 2023-07-30 16:39:40.215271: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e07ee00 of size 512 next 506
# 2023-07-30 16:39:40.215277: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e07f000 of size 256 next 508
# 2023-07-30 16:39:40.215283: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e07f100 of size 256 next 509
# 2023-07-30 16:39:40.215290: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e07f200 of size 2048 next 213
# 2023-07-30 16:39:40.215296: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e07fa00 of size 3072 next 514
# 2023-07-30 16:39:40.215302: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e080600 of size 256 next 515
# 2023-07-30 16:39:40.215308: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e080700 of size 256 next 516
# 2023-07-30 16:39:40.215314: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e080800 of size 18432 next 530
# 2023-07-30 16:39:40.215320: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e085000 of size 256 next 531
# 2023-07-30 16:39:40.215326: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e085100 of size 256 next 532
# 2023-07-30 16:39:40.215333: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e085200 of size 524288 next 315
# 2023-07-30 16:39:40.215339: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e105200 of size 4096 next 2482
# 2023-07-30 16:39:40.215346: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e106200 of size 4096 next 2483
# 2023-07-30 16:39:40.215352: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e107200 of size 1024 next 2484
# 2023-07-30 16:39:40.215358: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e107600 of size 1024 next 2485
# 2023-07-30 16:39:40.215364: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e107a00 of size 1024 next 2486
# 2023-07-30 16:39:40.215370: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e107e00 of size 1024 next 2487
# 2023-07-30 16:39:40.215376: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e108200 of size 1024 next 2490
# 2023-07-30 16:39:40.215382: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e108600 of size 1024 next 2491
# 2023-07-30 16:39:40.215389: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e108a00 of size 1024 next 2492
# 2023-07-30 16:39:40.215395: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e108e00 of size 1024 next 2493
# 2023-07-30 16:39:40.215401: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e109200 of size 4096 next 2495
# 2023-07-30 16:39:40.215407: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e10a200 of size 4096 next 2496
# 2023-07-30 16:39:40.215413: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e10b200 of size 4096 next 2497
# 2023-07-30 16:39:40.215419: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e10c200 of size 4096 next 2498
# 2023-07-30 16:39:40.215426: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e10d200 of size 4096 next 2499
# 2023-07-30 16:39:40.215432: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e10e200 of size 1024 next 2500
# 2023-07-30 16:39:40.215438: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e10e600 of size 1024 next 2501
# 2023-07-30 16:39:40.215444: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e10ea00 of size 1024 next 2502
# 2023-07-30 16:39:40.215450: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e10ee00 of size 1024 next 2503
# 2023-07-30 16:39:40.215456: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e10f200 of size 1024 next 2506
# 2023-07-30 16:39:40.215462: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e10f600 of size 1024 next 2507
# 2023-07-30 16:39:40.215468: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e10fa00 of size 1024 next 2508
# 2023-07-30 16:39:40.215474: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e10fe00 of size 1024 next 2509
# 2023-07-30 16:39:40.215480: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e110200 of size 4096 next 2511
# 2023-07-30 16:39:40.215486: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e111200 of size 4096 next 2512
# 2023-07-30 16:39:40.215507: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e112200 of size 4096 next 2513
# 2023-07-30 16:39:40.215513: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e113200 of size 4096 next 2514
# 2023-07-30 16:39:40.215519: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e114200 of size 4096 next 2515
# 2023-07-30 16:39:40.215525: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e115200 of size 1024 next 2516
# 2023-07-30 16:39:40.215542: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e115600 of size 1024 next 2517
# 2023-07-30 16:39:40.215547: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e115a00 of size 1024 next 2518
# 2023-07-30 16:39:40.215553: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e115e00 of size 1024 next 2519
# 2023-07-30 16:39:40.215559: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e116200 of size 1024 next 2522
# 2023-07-30 16:39:40.215564: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e116600 of size 1024 next 2523
# 2023-07-30 16:39:40.215570: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e116a00 of size 1024 next 2524
# 2023-07-30 16:39:40.215576: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e116e00 of size 1024 next 2525
# 2023-07-30 16:39:40.215581: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e117200 of size 4096 next 2527
# 2023-07-30 16:39:40.215587: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e118200 of size 4096 next 2528
# 2023-07-30 16:39:40.215592: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e119200 of size 4096 next 2529
# 2023-07-30 16:39:40.215598: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e11a200 of size 4096 next 2530
# 2023-07-30 16:39:40.215604: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e11b200 of size 4096 next 2531
# 2023-07-30 16:39:40.215610: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e11c200 of size 1024 next 2532
# 2023-07-30 16:39:40.215615: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e11c600 of size 1024 next 2533
# 2023-07-30 16:39:40.215621: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e11ca00 of size 1024 next 2534
# 2023-07-30 16:39:40.215626: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e11ce00 of size 1024 next 2535
# 2023-07-30 16:39:40.215632: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e11d200 of size 1024 next 2538
# 2023-07-30 16:39:40.215638: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e11d600 of size 1024 next 2539
# 2023-07-30 16:39:40.215643: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e11da00 of size 1024 next 2540
# 2023-07-30 16:39:40.215649: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e11de00 of size 1024 next 2541
# 2023-07-30 16:39:40.215655: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e11e200 of size 4096 next 2543
# 2023-07-30 16:39:40.215660: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e11f200 of size 4096 next 2544
# 2023-07-30 16:39:40.215666: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e120200 of size 4096 next 2545
# 2023-07-30 16:39:40.215671: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e121200 of size 4096 next 2546
# 2023-07-30 16:39:40.215677: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e122200 of size 4096 next 2547
# 2023-07-30 16:39:40.215683: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e123200 of size 1024 next 2548
# 2023-07-30 16:39:40.215688: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e123600 of size 1024 next 2549
# 2023-07-30 16:39:40.215694: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e123a00 of size 1024 next 2550
# 2023-07-30 16:39:40.215699: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e123e00 of size 1024 next 2551
# 2023-07-30 16:39:40.215705: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e124200 of size 1024 next 2554
# 2023-07-30 16:39:40.215711: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e124600 of size 1024 next 2555
# 2023-07-30 16:39:40.215716: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e124a00 of size 1024 next 2556
# 2023-07-30 16:39:40.215722: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 2ae07e124e00 of size 1024 next 2311
# ...
# 2023-07-30 16:39:40.231926: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 3225088 totalling 3.08MiB
# 2023-07-30 16:39:40.231933: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 3276800 totalling 3.12MiB
# 2023-07-30 16:39:40.231939: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 3670016 totalling 3.50MiB
# 2023-07-30 16:39:40.231946: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 3958528 totalling 3.77MiB
# 2023-07-30 16:39:40.231952: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 3997696 totalling 3.81MiB
# 2023-07-30 16:39:40.231959: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 4144896 totalling 3.95MiB
# 2023-07-30 16:39:40.231965: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 15 Chunks of size 4194304 totalling 60.00MiB
# 2023-07-30 16:39:40.231972: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 4390912 totalling 4.19MiB
# 2023-07-30 16:39:40.231978: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 4665344 totalling 4.45MiB
# 2023-07-30 16:39:40.231985: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 5242880 totalling 5.00MiB
# 2023-07-30 16:39:40.231991: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 6291456 totalling 6.00MiB
# 2023-07-30 16:39:40.231998: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 7586048 totalling 7.23MiB
# 2023-07-30 16:39:40.232005: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 5 Chunks of size 8388608 totalling 40.00MiB
# 2023-07-30 16:39:40.232011: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 10 Chunks of size 9437184 totalling 90.00MiB
# 2023-07-30 16:39:40.232018: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 12870656 totalling 12.27MiB
# 2023-07-30 16:39:40.232025: I tensorflow/core/common_runtime/bfc_allocator.cc:1040] Sum Total of in-use chunks: 813.88MiB
# 2023-07-30 16:39:40.232032: I tensorflow/core/common_runtime/bfc_allocator.cc:1042] total_region_allocated_bytes_: 853737472 memory_limit_: 853737472 available bytes: 0 curr_region_allocation_bytes_: 1707474944
# 2023-07-30 16:39:40.232045: I tensorflow/core/common_runtime/bfc_allocator.cc:1048] Stats:
# Limit:                       853737472
# InUse:                       853417984
# MaxInUse:                    853417984
# NumAllocs:                        6284
# MaxAllocSize:                264241152
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2023-07-30 16:39:40.232132: W tensorflow/core/common_runtime/bfc_allocator.cc:441] ****************************************************************************************************
# 2023-07-30 16:39:40.232166: W tensorflow/core/framework/op_kernel.cc:1763] OP_REQUIRES failed at constant_op.cc:161 : Resource exhausted: OOM when allocating tensor with shape[3,3,512,512] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Cell In[29], line 7
#       3 class_weights = compute_class_weight(class_weight='balanced',classes=np.unique(y_train_integers),
#       4                                      y = y_train_integers)
#       5 d_class_weights = dict(enumerate(class_weights))
# ----> 7 history = model.fit(
#       8     train_joint_dataset.batch(16),
#       9     validation_data=val_joint_dataset.batch(16),
#      10     class_weight = d_class_weights,
#      11     epochs=epochs,
#      12     callbacks=[early_stopping_callback]
#      13 )
#
# File /glade/work/jhayron/conda-envs/cnn_wr/lib/python3.9/site-packages/tensorflow/python/keras/engine/training.py:1100, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1093 with trace.Trace(
#    1094     'train',
#    1095     epoch_num=epoch,
#    1096     step_num=step,
#    1097     batch_size=batch_size,
#    1098     _r=1):
#    1099   callbacks.on_train_batch_begin(step)
# -> 1100   tmp_logs = self.train_function(iterator)
#    1101   if data_handler.should_sync:
#    1102     context.async_wait()
#
# File /glade/work/jhayron/conda-envs/cnn_wr/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py:828, in Function.__call__(self, *args, **kwds)
#     826 tracing_count = self.experimental_get_tracing_count()
#     827 with trace.Trace(self._name) as tm:
# --> 828   result = self._call(*args, **kwds)
#     829   compiler = "xla" if self._experimental_compile else "nonXla"
#     830   new_tracing_count = self.experimental_get_tracing_count()
#
# File /glade/work/jhayron/conda-envs/cnn_wr/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py:871, in Function._call(self, *args, **kwds)
#     868 try:
#     869   # This is the first call of __call__, so we have to initialize.
#     870   initializers = []
# --> 871   self._initialize(args, kwds, add_initializers_to=initializers)
#     872 finally:
#     873   # At this point we know that the initialization is complete (or less
#     874   # interestingly an exception was raised) so we no longer need a lock.
#     875   self._lock.release()
#
# File /glade/work/jhayron/conda-envs/cnn_wr/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py:725, in Function._initialize(self, args, kwds, add_initializers_to)
#     722 self._lifted_initializer_graph = lifted_initializer_graph
#     723 self._graph_deleter = FunctionDeleter(self._lifted_initializer_graph)
#     724 self._concrete_stateful_fn = (
# --> 725     self._stateful_fn._get_concrete_function_internal_garbage_collected(  # pylint: disable=protected-access
#     726         *args, **kwds))
#     728 def invalid_creator_scope(*unused_args, **unused_kwds):
#     729   """Disables variable creation."""
#
# File /glade/work/jhayron/conda-envs/cnn_wr/lib/python3.9/site-packages/tensorflow/python/eager/function.py:2969, in Function._get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#    2967   args, kwargs = None, None
#    2968 with self._lock:
# -> 2969   graph_function, _ = self._maybe_define_function(args, kwargs)
#    2970 return graph_function
#
# File /glade/work/jhayron/conda-envs/cnn_wr/lib/python3.9/site-packages/tensorflow/python/eager/function.py:3361, in Function._maybe_define_function(self, args, kwargs)
#    3357   return self._define_function_with_shape_relaxation(
#    3358       args, kwargs, flat_args, filtered_flat_args, cache_key_context)
#    3360 self._function_cache.missed.add(call_context_key)
# -> 3361 graph_function = self._create_graph_function(args, kwargs)
#    3362 self._function_cache.primary[cache_key] = graph_function
#    3364 return graph_function, filtered_flat_args
#
# File /glade/work/jhayron/conda-envs/cnn_wr/lib/python3.9/site-packages/tensorflow/python/eager/function.py:3196, in Function._create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3191 missing_arg_names = [
#    3192     "%s_%d" % (arg, i) for i, arg in enumerate(missing_arg_names)
#    3193 ]
#    3194 arg_names = base_arg_names + missing_arg_names
#    3195 graph_function = ConcreteFunction(
# -> 3196     func_graph_module.func_graph_from_py_func(
#    3197         self._name,
#    3198         self._python_function,
#    3199         args,
#    3200         kwargs,
#    3201         self.input_signature,
#    3202         autograph=self._autograph,
#    3203         autograph_options=self._autograph_options,
#    3204         arg_names=arg_names,
#    3205         override_flat_arg_shapes=override_flat_arg_shapes,
#    3206         capture_by_value=self._capture_by_value),
#    3207     self._function_attributes,
#    3208     function_spec=self.function_spec,
#    3209     # Tell the ConcreteFunction to clean up its graph once it goes out of
#    3210     # scope. This is not the default behavior since it gets used in some
#    3211     # places (like Keras) where the FuncGraph lives longer than the
#    3212     # ConcreteFunction.
#    3213     shared_func_graph=False)
#    3214 return graph_function
#
# File /glade/work/jhayron/conda-envs/cnn_wr/lib/python3.9/site-packages/tensorflow/python/framework/func_graph.py:990, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     987 else:
#     988   _, original_func = tf_decorator.unwrap(python_func)
# --> 990 func_outputs = python_func(*func_args, **func_kwargs)
#     992 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#     993 # TensorArrays and `None`s.
#     994 func_outputs = nest.map_structure(convert, func_outputs,
#     995                                   expand_composites=True)
#
# File /glade/work/jhayron/conda-envs/cnn_wr/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py:634, in Function._defun_with_scope.<locals>.wrapped_fn(*args, **kwds)
#     632     xla_context.Exit()
#     633 else:
# --> 634   out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     635 return out
#
# File /glade/work/jhayron/conda-envs/cnn_wr/lib/python3.9/site-packages/tensorflow/python/framework/func_graph.py:977, in func_graph_from_py_func.<locals>.wrapper(*args, **kwargs)
#     975 except Exception as e:  # pylint:disable=broad-except
#     976   if hasattr(e, "ag_error_metadata"):
# --> 977     raise e.ag_error_metadata.to_exception(e)
#     978   else:
#     979     raise
#
# ResourceExhaustedError: in user code:
#
#     /glade/work/jhayron/conda-envs/cnn_wr/lib/python3.9/site-packages/tensorflow/python/keras/engine/training.py:805 train_function  *
#         return step_function(self, iterator)
#     /glade/work/jhayron/conda-envs/cnn_wr/lib/python3.9/site-packages/tensorflow/python/keras/engine/training.py:795 step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     /glade/work/jhayron/conda-envs/cnn_wr/lib/python3.9/site-packages/tensorflow/python/distribute/distribute_lib.py:1259 run
#         return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     /glade/work/jhayron/conda-envs/cnn_wr/lib/python3.9/site-packages/tensorflow/python/distribute/distribute_lib.py:2730 call_for_each_replica
#         return self._call_for_each_replica(fn, args, kwargs)
#     /glade/work/jhayron/conda-envs/cnn_wr/lib/python3.9/site-packages/tensorflow/python/distribute/distribute_lib.py:3417 _call_for_each_replica
#         return fn(*args, **kwargs)
#     /glade/work/jhayron/conda-envs/cnn_wr/lib/python3.9/site-packages/tensorflow/python/keras/engine/training.py:788 run_step  **
#         outputs = model.train_step(data)
#     /glade/work/jhayron/conda-envs/cnn_wr/lib/python3.9/site-packages/tensorflow/python/keras/engine/training.py:757 train_step
#         self.optimizer.minimize(loss, self.trainable_variables, tape=tape)
#     /glade/work/jhayron/conda-envs/cnn_wr/lib/python3.9/site-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:498 minimize
#         return self.apply_gradients(grads_and_vars, name=name)
#     /glade/work/jhayron/conda-envs/cnn_wr/lib/python3.9/site-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:604 apply_gradients
#         self._create_all_weights(var_list)
#     /glade/work/jhayron/conda-envs/cnn_wr/lib/python3.9/site-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:783 _create_all_weights
#         self._create_slots(var_list)
#     /glade/work/jhayron/conda-envs/cnn_wr/lib/python3.9/site-packages/tensorflow/python/keras/optimizer_v2/adam.py:127 _create_slots
#         self.add_slot(var, 'm')
#     /glade/work/jhayron/conda-envs/cnn_wr/lib/python3.9/site-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:847 add_slot
#         weight = tf_variables.Variable(
#     /glade/work/jhayron/conda-envs/cnn_wr/lib/python3.9/site-packages/tensorflow/python/ops/variables.py:262 __call__
#         return cls._variable_v2_call(*args, **kwargs)
#     /glade/work/jhayron/conda-envs/cnn_wr/lib/python3.9/site-packages/tensorflow/python/ops/variables.py:244 _variable_v2_call
#         return previous_getter(
#     /glade/work/jhayron/conda-envs/cnn_wr/lib/python3.9/site-packages/tensorflow/python/ops/variables.py:67 getter
#         return captured_getter(captured_previous, **kwargs)
#     /glade/work/jhayron/conda-envs/cnn_wr/lib/python3.9/site-packages/tensorflow/python/distribute/distribute_lib.py:3332 creator
#         return next_creator(**kwargs)
#     /glade/work/jhayron/conda-envs/cnn_wr/lib/python3.9/site-packages/tensorflow/python/ops/variables.py:67 getter
#         return captured_getter(captured_previous, **kwargs)
#     /glade/work/jhayron/conda-envs/cnn_wr/lib/python3.9/site-packages/tensorflow/python/distribute/distribute_lib.py:3332 creator
#         return next_creator(**kwargs)
#     /glade/work/jhayron/conda-envs/cnn_wr/lib/python3.9/site-packages/tensorflow/python/ops/variables.py:67 getter
#         return captured_getter(captured_previous, **kwargs)
#     /glade/work/jhayron/conda-envs/cnn_wr/lib/python3.9/site-packages/tensorflow/python/distribute/distribute_lib.py:3332 creator
#         return next_creator(**kwargs)
#     /glade/work/jhayron/conda-envs/cnn_wr/lib/python3.9/site-packages/tensorflow/python/ops/variables.py:67 getter
#         return captured_getter(captured_previous, **kwargs)
#     /glade/work/jhayron/conda-envs/cnn_wr/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py:712 variable_capturing_scope
#         v = UnliftedInitializerVariable(
#     /glade/work/jhayron/conda-envs/cnn_wr/lib/python3.9/site-packages/tensorflow/python/ops/variables.py:264 __call__
#         return super(VariableMetaclass, cls).__call__(*args, **kwargs)
#     /glade/work/jhayron/conda-envs/cnn_wr/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py:227 __init__
#         initial_value = initial_value()
#     /glade/work/jhayron/conda-envs/cnn_wr/lib/python3.9/site-packages/tensorflow/python/keras/initializers/initializers_v2.py:139 __call__
#         return super(Zeros, self).__call__(shape, dtype=_get_dtype(dtype), **kwargs)
#     /glade/work/jhayron/conda-envs/cnn_wr/lib/python3.9/site-packages/tensorflow/python/ops/init_ops_v2.py:154 __call__
#         return array_ops.zeros(shape, dtype)
#     /glade/work/jhayron/conda-envs/cnn_wr/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:201 wrapper
#         return target(*args, **kwargs)
#     /glade/work/jhayron/conda-envs/cnn_wr/lib/python3.9/site-packages/tensorflow/python/ops/array_ops.py:2819 wrapped
#         tensor = fun(*args, **kwargs)
#     /glade/work/jhayron/conda-envs/cnn_wr/lib/python3.9/site-packages/tensorflow/python/ops/array_ops.py:2880 zeros
#         output = fill(shape, constant(zero, dtype=dtype), name=name)
#     /glade/work/jhayron/conda-envs/cnn_wr/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:201 wrapper
#         return target(*args, **kwargs)
#     /glade/work/jhayron/conda-envs/cnn_wr/lib/python3.9/site-packages/tensorflow/python/ops/array_ops.py:239 fill
#         result = gen_array_ops.fill(dims, value, name=name)
#     /glade/work/jhayron/conda-envs/cnn_wr/lib/python3.9/site-packages/tensorflow/python/ops/gen_array_ops.py:3348 fill
#         _ops.raise_from_not_ok_status(e, name)
#     /glade/work/jhayron/conda-envs/cnn_wr/lib/python3.9/site-packages/tensorflow/python/framework/ops.py:6862 raise_from_not_ok_status
#         six.raise_from(core._status_to_exception(e.code, message), None)
#     <string>:3 raise_from
#
#
#     ResourceExhaustedError: OOM when allocating tensor with shape[3,3,512,512] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc [Op:Fill]
